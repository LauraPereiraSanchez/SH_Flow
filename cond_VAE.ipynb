# %%
from helpers import duplicates, load_data, torch_loader
from plotting import GetFractions, PlotPNN 
# plotting
import matplotlib.pyplot as plt


# load

ignore_list = ['X400_S170', 'X500_S170', 'X170_S30', 'X245_S30', 'X205_S30', 'X400_S30', 'X500_S30', 'X300_S30', 'X180_S50', 'X190_S50']

blind_signals = ['X245_S70', 'X750_S200', 'X500_S300', 'X600_S110', 'X200_S90', 'X400_S170' 'X300_S70', 'X600_S170',  'X205_S50','X300_S70']

#data, hold_data = load_data("data.parquet", not_use_list=ignore_list)

data, hold_data = load_data("data.parquet", exclude_list = blind_signals, not_use_list=ignore_list)

seen_signals = set(data['signal'])

print("# signals used for training = ", len(seen_signals))

batch_size = len(seen_signals)*64*5

print("Batch size = ", batch_size)

GetFractions(data)

GetFractions(hold_data)

'''
for s in set(data['signal']):
    mX = int(s.split("_")[0].split("X")[-1])
    mS = int(s.split("_")[1].split("S")[-1])

    PlotPNN(data, mX, mS)

'''

# Define features and context variables
features = ["PNN_score"] # The distribution you want to learn
context = ["real_mX", "real_mS"] # These are your conditional parameters

train_loader, val_loader, feature_scaler, context_scaler = torch_loader(data, features, context, batch_size=batch_size)
# Out:
# No duplicates found
#
#  Signals to use for training:
# ['X400_S110', 'X1000_S170', 'X200_S70', 'X250_S100', 'X500_S70', 'X750_S170', 'X245_S90', 'X185_S30', 'X875_S200', 'X675_S400', 'X1000_S400', 'X350_S170', 'X240_S110', 'X300_S110', 'X1000_S300', 'X600_S40', 'X750_S110', 'X600_S300', 'X500_S200', 'X250_S110', 'X600_S70', 'X400_S200', 'X210_S70', 'X225_S50', 'X600_S400', 'X400_S70', 'X1000_S200', 'X245_S50', 'X1000_S500', 'X220_S90', 'X225_S70', 'X400_S250', 'X750_S70', 'X1000_S70', 'X750_S400', 'X750_S300', 'X225_S30', 'X240_S100', 'X750_S500', 'X950_S90', 'X500_S110']
#
#  Signals to hold for testing:
# ['X245_S70', 'X750_S200', 'X500_S300', 'X600_S110', 'X200_S90', 'X400_S170X300_S70', 'X600_S170', 'X205_S50', 'X300_S70']
#
#  Unused signals:
# ['X500_S30', 'X245_S30', 'X170_S30', 'X400_S30', 'X300_S30', 'X180_S50', 'X205_S30', 'X190_S50', 'X400_S170', 'X500_S170']
# # signals used for training =  41
# Batch size =  13120

# %%
def count(loader, mX, mS):
    for i, batch in enumerate(loader):
        data, labels = batch
        count = 0
        for j in labels:
            if (int(j[0]) == mX) and (int(j[1]) == mS):
                count +=1
        print("mX = ", mX, " and mS = ", mS, " -> ", count, " events")
    
        break
    return 

print("\n Signal events in training set \n ")
for s in seen_signals:
    mX = int(s.split("_")[0].split("X")[-1])
    mS = int( s.split("_S")[-1])
    
    count(train_loader, mX, mS)

print("\n Signal events in validation set \n")
for s in seen_signals: #set(hold_data['signal']):
    mX = int(s.split("_")[0].split("X")[-1])
    mS = int( s.split("_S")[-1])
    
    count(val_loader, mX, mS)
# Out:
#  Signal events in training set
#
# mX =  400  and mS =  110  ->  276  events
# mX =  1000  and mS =  170  ->  502  events
# mX =  200  and mS =  70  ->  55  events
# mX =  250  and mS =  100  ->  167  events
# mX =  500  and mS =  70  ->  352  events
# mX =  750  and mS =  170  ->  485  events
# mX =  245  and mS =  90  ->  126  events
# mX =  185  and mS =  30  ->  88  events
# mX =  875  and mS =  200  ->  524  events
# mX =  675  and mS =  400  ->  458  events
# mX =  1000  and mS =  400  ->  581  events
# mX =  350  and mS =  170  ->  297  events
# mX =  750  and mS =  110  ->  503  events
# mX =  240  and mS =  110  ->  164  events
# mX =  300  and mS =  110  ->  207  events
# mX =  1000  and mS =  300  ->  564  events
# mX =  600  and mS =  40  ->  508  events
# mX =  600  and mS =  300  ->  438  events
# mX =  500  and mS =  200  ->  420  events
# mX =  250  and mS =  110  ->  169  events
# mX =  600  and mS =  70  ->  435  events
# mX =  400  and mS =  200  ->  332  events
# mX =  210  and mS =  70  ->  86  events
# mX =  225  and mS =  50  ->  62  events
# mX =  600  and mS =  400  ->  397  events
# mX =  400  and mS =  70  ->  266  events
# mX =  1000  and mS =  200  ->  581  events
# mX =  245  and mS =  50  ->  73  events
# mX =  1000  and mS =  500  ->  535  events
# mX =  220  and mS =  90  ->  118  events
# mX =  225  and mS =  70  ->  81  events
# mX =  400  and mS =  250  ->  338  events
# mX =  750  and mS =  70  ->  322  events
# mX =  1000  and mS =  70  ->  209  events
# mX =  750  and mS =  400  ->  500  events
# mX =  750  and mS =  300  ->  490  events
# mX =  225  and mS =  30  ->  75  events
# mX =  240  and mS =  100  ->  161  events
# mX =  750  and mS =  500  ->  434  events
# mX =  950  and mS =  90  ->  420  events
# mX =  500  and mS =  110  ->  372  events
#
#  Signal events in validation set
#
# mX =  400  and mS =  110  ->  287  events
# mX =  1000  and mS =  170  ->  538  events
# mX =  200  and mS =  70  ->  61  events
# mX =  250  and mS =  100  ->  146  events
# mX =  500  and mS =  70  ->  342  events
# mX =  750  and mS =  170  ->  471  events
# mX =  245  and mS =  90  ->  147  events
# mX =  185  and mS =  30  ->  122  events
# mX =  875  and mS =  200  ->  511  events
# mX =  675  and mS =  400  ->  445  events
# mX =  1000  and mS =  400  ->  575  events
# mX =  350  and mS =  170  ->  313  events
# mX =  750  and mS =  110  ->  462  events
# mX =  240  and mS =  110  ->  187  events
# mX =  300  and mS =  110  ->  206  events
# mX =  1000  and mS =  300  ->  602  events
# mX =  600  and mS =  40  ->  482  events
# mX =  600  and mS =  300  ->  457  events
# mX =  500  and mS =  200  ->  382  events
# mX =  250  and mS =  110  ->  188  events
# mX =  600  and mS =  70  ->  386  events
# mX =  400  and mS =  200  ->  339  events
# mX =  210  and mS =  70  ->  53  events
# mX =  225  and mS =  50  ->  68  events
# mX =  600  and mS =  400  ->  401  events
# mX =  400  and mS =  70  ->  239  events
# mX =  1000  and mS =  200  ->  538  events
# mX =  245  and mS =  50  ->  94  events
# mX =  1000  and mS =  500  ->  558  events
# mX =  220  and mS =  90  ->  110  events
# mX =  225  and mS =  70  ->  86  events
# mX =  400  and mS =  250  ->  319  events
# mX =  750  and mS =  70  ->  360  events
# mX =  1000  and mS =  70  ->  178  events
# mX =  750  and mS =  400  ->  486  events
# mX =  750  and mS =  300  ->  549  events
# mX =  225  and mS =  30  ->  78  events
# mX =  240  and mS =  100  ->  148  events
# mX =  750  and mS =  500  ->  462  events
# mX =  950  and mS =  90  ->  399  events
# mX =  500  and mS =  110  ->  345  events

# %%
# network
import torch
from torch import nn
from torch.nn import functional as F
from torchsummary import summary
from torchvision.utils import save_image
import torchvision
import torch.optim as optim


class Encoder(nn.Module):
    def __init__(self, input_dim, latent_dim, label_dim, hidden_dim=400):
        super(Encoder, self).__init__()
        self.fc1 = nn.Linear(input_dim + label_dim, hidden_dim) 
        self.fc2 = nn.Linear(hidden_dim, hidden_dim)
        self.fc31 = nn.Linear(hidden_dim, latent_dim)  # Mean
        self.fc32 = nn.Linear(hidden_dim, latent_dim)  # Log-variance

    def forward(self, x, labels):
        x = torch.cat([x, labels], dim=1)
        h1 = F.relu(self.fc1(x))
        h2 =  F.relu(self.fc2(h1))
        mu =  self.fc31(h2)
        logvar = self.fc32(h2)
        logvar = torch.clamp(logvar, max=30)  # Choose limits based on your specific needs
        return mu, logvar

class Decoder(nn.Module):
    def __init__(self, input_dim, latent_dim, label_dim, output_dim=1, hidden_dim=400):
        super(Decoder, self).__init__()
        self.fc4 = nn.Linear(latent_dim + label_dim, hidden_dim)
        self.fc5 = nn.Linear(hidden_dim, hidden_dim)
        self.fc_mu = nn.Linear(hidden_dim, output_dim)       # Predict the mean
        #self.fc_logvar = nn.Linear(hidden_dim, output_dim)  # Predict the log-variance

    def forward(self, z, labels):
        z = torch.cat([z, labels], dim=1)
        h4 = F.relu(self.fc4(z))
        h5 = F.relu(self.fc5(h4))
        mu = F.sigmoid(self.fc_mu(h5))  # Mean of the distribution, should be in the 0 to 1 range hence the sigmoid
        #logvar = self.fc_logvar(h5)  # Log-variance of the distribution
        #logvar = torch.clamp(logvar, min=-30, max=30)  # Choose limits based on your specific needs

        return mu#, logvar
 #torch.sigmoid(raw_output) #torch.clamp(raw_output, min=0.0, max=1.0)  #torch.sigmoid(raw_output))

class CVAE(nn.Module):
    def __init__(self, input_dim, latent_dim, label_dim, hidden_dim=400):
        super(CVAE, self).__init__()
        self.encoder = Encoder(input_dim, latent_dim, label_dim, hidden_dim=400)
        self.decoder = Decoder(input_dim, latent_dim, label_dim, hidden_dim=400)

    def reparameterize(self, mu, log_var):
        std = torch.exp(0.5 * log_var)
        eps = torch.randn_like(std)
        return mu + eps * std

    def forward(self, x, labels):
        mu, log_var = self.encoder(x, labels)
        z = self.reparameterize(mu, log_var)
        #recon_mu, recon_log_var = self.decoder(z, labels) # for gaussian loss in NLL
        recon_mu = self.decoder(z, labels) # for bernoulli loss in NLL

        #return recon_mu, recon_log_var, mu, log_var
        return recon_mu, mu, log_var

def bernoulli_nll_loss(x, mu):
    # Compute the negative log likelihood for a Bernoulli distribution
    nll = -torch.sum(x * torch.log(mu + 1e-6) + (1 - x) * torch.log(1 - mu + 1e-6), dim=1)  # sum over features
    return torch.mean(nll)  # mean over batch

def nll_loss(recon_mu, recon_logvar, x):
    """
    Compute the Negative Log-Likelihood (NLL) loss for Gaussian outputs.

    Args:
        recon_mu (torch.Tensor): Predicted mean of the Gaussian (decoder output).
        recon_logvar (torch.Tensor): Predicted log-variance of the Gaussian (decoder output).
        x (torch.Tensor): Ground truth data.

    Returns:
        torch.Tensor: NLL loss.
    """
    recon_var = torch.exp(recon_logvar)  # Variance = exp(log-variance)
    #print("calculating nll")
    #print("first term ", recon_logvar)
    #print("second term ",((x - recon_mu) ** 2) / (recon_var + 0.001))
    #print("x ", x)
    #print("reconstructed mu ", recon_mu)
    
    nll = 0.5 * torch.sum(recon_logvar + ((x - recon_mu) ** 2) / (recon_var + 0.00001))
    return nll

#def loss_function(recon_x, x, mu, log_var, beta=1.0):
def loss_function(recon_mu, recon_logvar, x, mu, log_var, beta=1.0):

    #reconstruction_loss = F.mse_loss(recon_x, x, reduction='sum')
    #reconstruction_loss = nll_loss(recon_mu, recon_logvar, x)
    reconstruction_loss = bernoulli_nll_loss(recon_mu, x) # variance is no longer needed

    kl_divergence = -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp())
    return reconstruction_loss + beta * kl_divergence

class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, patience=7, verbose=False, delta=0):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
        """
        self.patience = patience
        self.verbose = verbose
        self.delta = delta
        self.best_score = None
        self.epochs_no_improve = 0
        self.early_stop = False

    def __call__(self, val_loss):
        score = abs(val_loss)  # Assuming val_loss can be negative; otherwise, just use val_loss directly.

        if self.best_score is None:
            self.best_score = score
        elif score < self.best_score - self.delta:  # Changed to look for a decrease in loss
            self.best_score = score
            self.epochs_no_improve = 0
        else:
            self.epochs_no_improve += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.epochs_no_improve} out of {self.patience}')
            if self.epochs_no_improve >= self.patience:
                self.early_stop = True

# %%
import numpy as np
import pandas as pd


def generate_and_plot(df, model, labels, latent_dim, n_events = 1000):
    
    z = torch.randn(100, latent_dim).to(device)  # Adjust latent_dim to 30
    label_tensor = torch.tensor(np.tile(labels, n_events).reshape(n_events, 2)).to(device)
                              
    # Generate signal
    signal = generate_samples(model, z, label_tensor).to("cpu").detach().numpy()

    custom = np.linspace(0, 1, 20)

    if not df.empty:
        filtered_df = df[(df['real_mX'] == labels[0]) & (df['real_mS'] == labels[1])]
        plt.hist(filtered_df["PNN_score"][:len(signal)], alpha=0.7, density=True, bins=custom, label = "real")

    plt.hist(signal, alpha=0.7, density=True, bins=custom, label = "fake")
    plt.ylabel('Arbitrary units')
    plt.title('Distribution to learn')
    plt.xlim(0, 1)  # Force x-axis range to [0, 1]
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
def initialize_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_uniform_(m.weight)
        if m.bias is not None:
            m.bias.data.fill_(0.01)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Hyperparameters
input_dim = 1
latent_dim = 50
label_dim = 2 # mX and mS
hidden_dim = 100

beta = 1

model = CVAE(input_dim, latent_dim, label_dim, hidden_dim).to(device)
model.apply(initialize_weights) # Xe weights

optimizer = torch.optim.Adam(model.parameters(), lr=5e-3)
#scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', patience=4, factor=0.5)


early_stopping = EarlyStopping(patience=20, verbose=False)

dummy = pd.DataFrame()

def generate_samples(model, z, labels):
    decoder = model.decoder
    recon_mu, recon_logvar = decoder(z, labels)
    recon_var = torch.exp(recon_logvar)
    samples = recon_mu + torch.randn_like(recon_var) * torch.sqrt(recon_var)
    return samples

def train(epoch):
    model.train()
    train_loss = 0
    
    stop = False
    for batch_idx, (data, labels) in enumerate(train_loader):
        assert not torch.isnan(data).any(), "Input features contain NaNs"
        assert not torch.isnan(labels).any(), "Labels contain NaNs"
        data = data.to(device)
        labels = labels.to(device)
        optimizer.zero_grad()
        #recon_batch, mu, log_var = model(data, labels)
        #loss = loss_function(recon_batch, data, mu, log_var, beta=beta)
        #recon_mu, recon_logvar, mu, log_var = model(data, labels)
        recon_mu, mu, log_var = model(data, labels)

        assert not torch.isnan(mu).any(), "Encoder mean contains NaNs"
        assert not torch.isnan(log_var).any(), "Encoder variance contains NaNs"
        assert not torch.isnan(recon_mu).any(), "Decoder mean contains NaNs"
        #assert not torch.isnan(recon_logvar).any(), "Decoder variance contains NaNs"

        #loss = loss_function(recon_mu, recon_logvar, data, mu, log_var, beta=beta)
        loss = loss_function(recon_mu, None, data, mu, log_var, beta=beta)
        
        loss.backward()
        train_loss += loss.item()
        optimizer.step()
        #if batch_idx % 2 == 0:
        #    print(f'Train Epoch: {epoch} [{batch_idx * len(data)}/{len(train_loader.dataset)} ({100. * batch_idx / len(train_loader):.0f}%)]\tLoss: {loss.item() / len(data):.6f}')

    avg_train_loss = train_loss / len(train_loader.dataset)
    
    model.eval()  # Set the model to evaluation mode
    val_loss = 0
    with torch.no_grad():  # No gradients needed
        for data, labels in val_loader:
            data = data.to(device)
            labels = labels.to(device)
            #recon, mu, log_var = model(data, labels)
            #loss = loss_function(recon, data, mu, log_var, beta=beta)
            #recon_mu, recon_logvar, mu, log_var = model(data, labels)
            #loss = loss_function(recon_mu, recon_logvar, data, mu, log_var)

            recon_mu, mu, log_var = model(data, labels)
            loss = loss_function(recon_mu, None, data, mu, log_var, beta=beta)

            val_loss += loss.item()

    avg_val_loss = val_loss / len(val_loader.dataset)
    # Print the current learning rate
    current_lr = optimizer.param_groups[0]['lr']

    if epoch %2 == 0:
        print(f'Epoch: {epoch} - Current Learning Rate: {current_lr}')
        print(f'====> Epoch: {epoch} Average training (validation) loss: {avg_train_loss:.4f} ({avg_val_loss:.4f})')
    if epoch %50 == 0:
        print(recon_mu)
        #generate_and_plot(dummy, model, [250, 100], latent_dim, 100)
        #generate_and_plot(dummy, model, [220, 50], latent_dim, 100)
    
    scheduler.step(avg_val_loss)  

    
    # Call to the early stopping
    early_stopping(avg_val_loss)
    if early_stopping.early_stop:
        print("Early stopping")
        stop = True

    return avg_train_loss, avg_val_loss, current_lr, stop



num_epochs = 10000
train_losses, val_losses, learning_rate = [], [],  []
for epoch in range(1, num_epochs + 1):
    t_loss, v_loss, lr, stop = train(epoch)        
    train_losses.append(t_loss)
    val_losses.append(v_loss)
    learning_rate.append(lr)
    
    #if epoch % 5 == 0:  # Generate images every 2 epochs
    #    generate_images(model, epoch)
    if stop: break
# Out:
# Epoch: 2 - Current Learning Rate: 0.005
# ====> Epoch: 2 Average training (validation) loss: 18360.2283 (16230.4673)
# Epoch: 4 - Current Learning Rate: 0.005
# ====> Epoch: 4 Average training (validation) loss: 13816.7651 (13224.5138)
# Epoch: 6 - Current Learning Rate: 0.005
# ====> Epoch: 6 Average training (validation) loss: 11477.2500 (10850.1890)
# Epoch: 8 - Current Learning Rate: 0.005
# ====> Epoch: 8 Average training (validation) loss: 9366.0692 (8853.0928)
# Epoch: 10 - Current Learning Rate: 0.005
# ====> Epoch: 10 Average training (validation) loss: 7770.1599 (7419.8819)
# Epoch: 12 - Current Learning Rate: 0.005
# ====> Epoch: 12 Average training (validation) loss: 6436.0249 (6125.7163)
# Epoch: 14 - Current Learning Rate: 0.005
# ====> Epoch: 14 Average training (validation) loss: 5351.4593 (5108.2967)
# Epoch: 16 - Current Learning Rate: 0.005
# ====> Epoch: 16 Average training (validation) loss: 4868.2465 (4748.2562)
# Epoch: 18 - Current Learning Rate: 0.005
# ====> Epoch: 18 Average training (validation) loss: 4513.8543 (4369.8410)
# Epoch: 20 - Current Learning Rate: 0.005
# ====> Epoch: 20 Average training (validation) loss: 4127.5335 (4025.2391)
# Epoch: 22 - Current Learning Rate: 0.005
# ====> Epoch: 22 Average training (validation) loss: 3896.4538 (3782.3750)
# Epoch: 24 - Current Learning Rate: 0.005
# ====> Epoch: 24 Average training (validation) loss: 3617.0782 (3532.6860)
# Epoch: 26 - Current Learning Rate: 0.005
# ====> Epoch: 26 Average training (validation) loss: 3383.2966 (3318.8639)
# Epoch: 28 - Current Learning Rate: 0.005
# ====> Epoch: 28 Average training (validation) loss: 3292.4727 (3149.4583)
# Epoch: 30 - Current Learning Rate: 0.005
# ====> Epoch: 30 Average training (validation) loss: 3140.3757 (3080.3324)
# Epoch: 32 - Current Learning Rate: 0.005
# ====> Epoch: 32 Average training (validation) loss: 3102.5416 (3017.4613)
# Epoch: 34 - Current Learning Rate: 0.005
# ====> Epoch: 34 Average training (validation) loss: 3011.0961 (2951.7892)
# Epoch: 36 - Current Learning Rate: 0.005
# ====> Epoch: 36 Average training (validation) loss: 2966.1910 (2878.9969)
# Epoch: 38 - Current Learning Rate: 0.005
# ====> Epoch: 38 Average training (validation) loss: 2946.2009 (2833.7355)
# Epoch: 40 - Current Learning Rate: 0.005
# ====> Epoch: 40 Average training (validation) loss: 2835.7993 (2773.2547)
# Epoch: 42 - Current Learning Rate: 0.005
# ====> Epoch: 42 Average training (validation) loss: 2847.0326 (2721.0159)
# Epoch: 44 - Current Learning Rate: 0.005
# ====> Epoch: 44 Average training (validation) loss: 2821.1679 (2649.0739)
# Epoch: 46 - Current Learning Rate: 0.005
# ====> Epoch: 46 Average training (validation) loss: 2754.7922 (2622.4891)
# Epoch: 48 - Current Learning Rate: 0.005
# ====> Epoch: 48 Average training (validation) loss: 2761.7602 (2589.3483)
# Epoch: 50 - Current Learning Rate: 0.005
# ====> Epoch: 50 Average training (validation) loss: 2741.7774 (2535.5734)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 52 - Current Learning Rate: 0.005
# ====> Epoch: 52 Average training (validation) loss: 2566.9542 (2452.1718)
# Epoch: 54 - Current Learning Rate: 0.005
# ====> Epoch: 54 Average training (validation) loss: 2490.0902 (2408.2768)
# Epoch: 56 - Current Learning Rate: 0.005
# ====> Epoch: 56 Average training (validation) loss: 2464.8112 (2384.3925)
# Epoch: 58 - Current Learning Rate: 0.005
# ====> Epoch: 58 Average training (validation) loss: 2504.2621 (2395.0963)
# Epoch: 60 - Current Learning Rate: 0.005
# ====> Epoch: 60 Average training (validation) loss: 2420.2954 (2343.7588)
# Epoch: 62 - Current Learning Rate: 0.005
# ====> Epoch: 62 Average training (validation) loss: 2450.6214 (2332.3391)
# Epoch: 64 - Current Learning Rate: 0.005
# ====> Epoch: 64 Average training (validation) loss: 2457.9271 (2308.2827)
# Epoch: 66 - Current Learning Rate: 0.005
# ====> Epoch: 66 Average training (validation) loss: 2479.3282 (2299.1665)
# Epoch: 68 - Current Learning Rate: 0.005
# ====> Epoch: 68 Average training (validation) loss: 2388.6716 (2269.4567)
# Epoch: 70 - Current Learning Rate: 0.005
# ====> Epoch: 70 Average training (validation) loss: 2454.1781 (2263.6525)
# Epoch: 72 - Current Learning Rate: 0.005
# ====> Epoch: 72 Average training (validation) loss: 2382.0584 (2221.4581)
# Epoch: 74 - Current Learning Rate: 0.005
# ====> Epoch: 74 Average training (validation) loss: 2460.4216 (2213.1562)
# Epoch: 76 - Current Learning Rate: 0.005
# ====> Epoch: 76 Average training (validation) loss: 2360.8995 (2172.4829)
# Epoch: 78 - Current Learning Rate: 0.005
# ====> Epoch: 78 Average training (validation) loss: 2322.8693 (2179.0500)
# Epoch: 80 - Current Learning Rate: 0.005
# ====> Epoch: 80 Average training (validation) loss: 2223.2465 (2143.3466)
# Epoch: 82 - Current Learning Rate: 0.005
# ====> Epoch: 82 Average training (validation) loss: 2280.2879 (2170.5034)
# Epoch: 84 - Current Learning Rate: 0.005
# ====> Epoch: 84 Average training (validation) loss: 2311.3729 (2166.6528)
# Epoch: 86 - Current Learning Rate: 0.005
# ====> Epoch: 86 Average training (validation) loss: 2219.0431 (2126.8303)
# Epoch: 88 - Current Learning Rate: 0.005
# ====> Epoch: 88 Average training (validation) loss: 2313.7591 (2110.1716)
# Epoch: 90 - Current Learning Rate: 0.005
# ====> Epoch: 90 Average training (validation) loss: 2363.5974 (2112.8514)
# Epoch: 92 - Current Learning Rate: 0.005
# ====> Epoch: 92 Average training (validation) loss: 2291.2455 (2121.7811)
# Epoch: 94 - Current Learning Rate: 0.005
# ====> Epoch: 94 Average training (validation) loss: 2297.8308 (2111.9653)
# Epoch: 96 - Current Learning Rate: 0.005
# ====> Epoch: 96 Average training (validation) loss: 2217.5275 (2072.4826)
# Epoch: 98 - Current Learning Rate: 0.005
# ====> Epoch: 98 Average training (validation) loss: 2352.1644 (2113.0289)
# Epoch: 100 - Current Learning Rate: 0.005
# ====> Epoch: 100 Average training (validation) loss: 2222.0734 (2062.7014)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 102 - Current Learning Rate: 0.005
# ====> Epoch: 102 Average training (validation) loss: 2289.2533 (2057.6398)
# Epoch: 104 - Current Learning Rate: 0.005
# ====> Epoch: 104 Average training (validation) loss: 2214.7061 (2057.3953)
# Epoch: 106 - Current Learning Rate: 0.005
# ====> Epoch: 106 Average training (validation) loss: 2270.4963 (2084.2457)
# Epoch: 108 - Current Learning Rate: 0.005
# ====> Epoch: 108 Average training (validation) loss: 2126.7600 (2012.7622)
# Epoch: 110 - Current Learning Rate: 0.005
# ====> Epoch: 110 Average training (validation) loss: 2208.1240 (2026.7150)
# Epoch: 112 - Current Learning Rate: 0.005
# ====> Epoch: 112 Average training (validation) loss: 2194.9062 (2037.0548)
# Epoch: 114 - Current Learning Rate: 0.0025
# ====> Epoch: 114 Average training (validation) loss: 1996.3130 (1990.6614)
# Epoch: 116 - Current Learning Rate: 0.0025
# ====> Epoch: 116 Average training (validation) loss: 1976.5353 (1976.4861)
# Epoch: 118 - Current Learning Rate: 0.0025
# ====> Epoch: 118 Average training (validation) loss: 1971.9440 (1972.5382)
# Epoch: 120 - Current Learning Rate: 0.0025
# ====> Epoch: 120 Average training (validation) loss: 1968.5947 (1969.2031)
# Epoch: 122 - Current Learning Rate: 0.0025
# ====> Epoch: 122 Average training (validation) loss: 1965.3355 (1965.9428)
# Epoch: 124 - Current Learning Rate: 0.0025
# ====> Epoch: 124 Average training (validation) loss: 1962.0828 (1962.6913)
# Epoch: 126 - Current Learning Rate: 0.0025
# ====> Epoch: 126 Average training (validation) loss: 1958.8021 (1959.4058)
# Epoch: 128 - Current Learning Rate: 0.0025
# ====> Epoch: 128 Average training (validation) loss: 1955.5153 (1956.1225)
# Epoch: 130 - Current Learning Rate: 0.0025
# ====> Epoch: 130 Average training (validation) loss: 1952.2179 (1952.8306)
# Epoch: 132 - Current Learning Rate: 0.0025
# ====> Epoch: 132 Average training (validation) loss: 1948.9763 (1949.6333)
# Epoch: 134 - Current Learning Rate: 0.0025
# ====> Epoch: 134 Average training (validation) loss: 1945.8345 (1946.5107)
# Epoch: 136 - Current Learning Rate: 0.0025
# ====> Epoch: 136 Average training (validation) loss: 1942.7762 (1943.4671)
# Epoch: 138 - Current Learning Rate: 0.0025
# ====> Epoch: 138 Average training (validation) loss: 1939.7015 (1940.3751)
# Epoch: 140 - Current Learning Rate: 0.0025
# ====> Epoch: 140 Average training (validation) loss: 1936.6008 (1937.2802)
# Epoch: 142 - Current Learning Rate: 0.0025
# ====> Epoch: 142 Average training (validation) loss: 1933.4632 (1934.1317)
# Epoch: 144 - Current Learning Rate: 0.0025
# ====> Epoch: 144 Average training (validation) loss: 1930.2907 (1930.9542)
# Epoch: 146 - Current Learning Rate: 0.0025
# ====> Epoch: 146 Average training (validation) loss: 1927.0861 (1927.7469)
# Epoch: 148 - Current Learning Rate: 0.0025
# ====> Epoch: 148 Average training (validation) loss: 1923.8429 (1924.4792)
# Epoch: 150 - Current Learning Rate: 0.0025
# ====> Epoch: 150 Average training (validation) loss: 1920.5690 (1921.2054)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 152 - Current Learning Rate: 0.0025
# ====> Epoch: 152 Average training (validation) loss: 1917.2700 (1917.8927)
# Epoch: 154 - Current Learning Rate: 0.0025
# ====> Epoch: 154 Average training (validation) loss: 1913.9408 (1914.5627)
# Epoch: 156 - Current Learning Rate: 0.0025
# ====> Epoch: 156 Average training (validation) loss: 1910.6140 (1911.2378)
# Epoch: 158 - Current Learning Rate: 0.0025
# ====> Epoch: 158 Average training (validation) loss: 1907.2582 (1907.8754)
# Epoch: 160 - Current Learning Rate: 0.0025
# ====> Epoch: 160 Average training (validation) loss: 1903.9132 (1904.5437)
# Epoch: 162 - Current Learning Rate: 0.0025
# ====> Epoch: 162 Average training (validation) loss: 1900.6036 (1901.2535)
# Epoch: 164 - Current Learning Rate: 0.0025
# ====> Epoch: 164 Average training (validation) loss: 1897.4102 (1898.1236)
# Epoch: 166 - Current Learning Rate: 0.0025
# ====> Epoch: 166 Average training (validation) loss: 1894.4368 (1895.2437)
# Epoch: 168 - Current Learning Rate: 0.0025
# ====> Epoch: 168 Average training (validation) loss: 1891.7986 (1892.6886)
# Epoch: 170 - Current Learning Rate: 0.0025
# ====> Epoch: 170 Average training (validation) loss: 1889.4045 (1890.3435)
# Epoch: 172 - Current Learning Rate: 0.0025
# ====> Epoch: 172 Average training (validation) loss: 1887.1104 (1888.0616)
# Epoch: 174 - Current Learning Rate: 0.0025
# ====> Epoch: 174 Average training (validation) loss: 1884.8490 (1885.8116)
# Epoch: 176 - Current Learning Rate: 0.0025
# ====> Epoch: 176 Average training (validation) loss: 1882.6146 (1883.5806)
# Epoch: 178 - Current Learning Rate: 0.0025
# ====> Epoch: 178 Average training (validation) loss: 1880.3906 (1881.3668)
# Epoch: 180 - Current Learning Rate: 0.0025
# ====> Epoch: 180 Average training (validation) loss: 1878.2041 (1879.1912)
# Epoch: 182 - Current Learning Rate: 0.0025
# ====> Epoch: 182 Average training (validation) loss: 1876.0690 (1877.0634)
# Epoch: 184 - Current Learning Rate: 0.0025
# ====> Epoch: 184 Average training (validation) loss: 1873.9749 (1875.0039)
# Epoch: 186 - Current Learning Rate: 0.0025
# ====> Epoch: 186 Average training (validation) loss: 1871.9678 (1873.0259)
# Epoch: 188 - Current Learning Rate: 0.0025
# ====> Epoch: 188 Average training (validation) loss: 1870.0909 (1871.1702)
# Epoch: 190 - Current Learning Rate: 0.0025
# ====> Epoch: 190 Average training (validation) loss: 1868.2673 (1869.3703)
# Epoch: 192 - Current Learning Rate: 0.0025
# ====> Epoch: 192 Average training (validation) loss: 1866.4965 (1867.6023)
# Epoch: 194 - Current Learning Rate: 0.0025
# ====> Epoch: 194 Average training (validation) loss: 1864.7312 (1865.8274)
# Epoch: 196 - Current Learning Rate: 0.0025
# ====> Epoch: 196 Average training (validation) loss: 1862.9567 (1864.0499)
# Epoch: 198 - Current Learning Rate: 0.0025
# ====> Epoch: 198 Average training (validation) loss: 1861.1509 (1862.2317)
# Epoch: 200 - Current Learning Rate: 0.0025
# ====> Epoch: 200 Average training (validation) loss: 1859.3153 (1860.4076)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 202 - Current Learning Rate: 0.0025
# ====> Epoch: 202 Average training (validation) loss: 1857.4692 (1858.5594)
# Epoch: 204 - Current Learning Rate: 0.0025
# ====> Epoch: 204 Average training (validation) loss: 1855.6490 (1856.7129)
# Epoch: 206 - Current Learning Rate: 0.0025
# ====> Epoch: 206 Average training (validation) loss: 1853.8762 (1854.8466)
# Epoch: 208 - Current Learning Rate: 0.0025
# ====> Epoch: 208 Average training (validation) loss: 1852.0451 (1853.0689)
# Epoch: 210 - Current Learning Rate: 0.0025
# ====> Epoch: 210 Average training (validation) loss: 1852.1253 (1851.4504)
# Epoch: 212 - Current Learning Rate: 0.0025
# ====> Epoch: 212 Average training (validation) loss: 1863.5458 (1851.6310)
# Epoch: 214 - Current Learning Rate: 0.0025
# ====> Epoch: 214 Average training (validation) loss: 1885.5317 (1854.8295)
# Epoch: 216 - Current Learning Rate: 0.0025
# ====> Epoch: 216 Average training (validation) loss: 1907.6348 (1855.4534)
# Epoch: 218 - Current Learning Rate: 0.0025
# ====> Epoch: 218 Average training (validation) loss: 1903.5464 (1850.3316)
# Epoch: 220 - Current Learning Rate: 0.00125
# ====> Epoch: 220 Average training (validation) loss: 1844.7541 (1845.1404)
# Epoch: 222 - Current Learning Rate: 0.00125
# ====> Epoch: 222 Average training (validation) loss: 1842.4468 (1843.7838)
# Epoch: 224 - Current Learning Rate: 0.00125
# ====> Epoch: 224 Average training (validation) loss: 1841.5202 (1842.9202)
# Epoch: 226 - Current Learning Rate: 0.00125
# ====> Epoch: 226 Average training (validation) loss: 1840.7114 (1842.1193)
# Epoch: 228 - Current Learning Rate: 0.00125
# ====> Epoch: 228 Average training (validation) loss: 1839.8971 (1841.3042)
# Epoch: 230 - Current Learning Rate: 0.00125
# ====> Epoch: 230 Average training (validation) loss: 1839.0842 (1840.4785)
# Epoch: 232 - Current Learning Rate: 0.00125
# ====> Epoch: 232 Average training (validation) loss: 1838.2528 (1839.6493)
# Epoch: 234 - Current Learning Rate: 0.00125
# ====> Epoch: 234 Average training (validation) loss: 1837.4181 (1838.8161)
# Epoch: 236 - Current Learning Rate: 0.00125
# ====> Epoch: 236 Average training (validation) loss: 1836.5707 (1837.9654)
# Epoch: 238 - Current Learning Rate: 0.00125
# ====> Epoch: 238 Average training (validation) loss: 1835.7208 (1837.1126)
# Epoch: 240 - Current Learning Rate: 0.00125
# ====> Epoch: 240 Average training (validation) loss: 1834.8580 (1836.2499)
# Epoch: 242 - Current Learning Rate: 0.00125
# ====> Epoch: 242 Average training (validation) loss: 1833.9904 (1835.3828)
# Epoch: 244 - Current Learning Rate: 0.00125
# ====> Epoch: 244 Average training (validation) loss: 1833.1104 (1834.4960)
# Epoch: 246 - Current Learning Rate: 0.00125
# ====> Epoch: 246 Average training (validation) loss: 1832.2227 (1833.6075)
# Epoch: 248 - Current Learning Rate: 0.00125
# ====> Epoch: 248 Average training (validation) loss: 1831.3293 (1832.7123)
# Epoch: 250 - Current Learning Rate: 0.00125
# ====> Epoch: 250 Average training (validation) loss: 1830.4254 (1831.8107)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 252 - Current Learning Rate: 0.00125
# ====> Epoch: 252 Average training (validation) loss: 1829.5153 (1830.8955)
# Epoch: 254 - Current Learning Rate: 0.00125
# ====> Epoch: 254 Average training (validation) loss: 1828.5898 (1829.9756)
# Epoch: 256 - Current Learning Rate: 0.00125
# ====> Epoch: 256 Average training (validation) loss: 1827.6686 (1829.0502)
# Epoch: 258 - Current Learning Rate: 0.00125
# ====> Epoch: 258 Average training (validation) loss: 1826.7279 (1828.1055)
# Epoch: 260 - Current Learning Rate: 0.00125
# ====> Epoch: 260 Average training (validation) loss: 1825.7845 (1827.1689)
# Epoch: 262 - Current Learning Rate: 0.00125
# ====> Epoch: 262 Average training (validation) loss: 1824.8420 (1826.2264)
# Epoch: 264 - Current Learning Rate: 0.00125
# ====> Epoch: 264 Average training (validation) loss: 1823.8852 (1825.2614)
# Epoch: 266 - Current Learning Rate: 0.00125
# ====> Epoch: 266 Average training (validation) loss: 1822.9288 (1824.3096)
# Epoch: 268 - Current Learning Rate: 0.00125
# ====> Epoch: 268 Average training (validation) loss: 1821.9728 (1823.3487)
# Epoch: 270 - Current Learning Rate: 0.00125
# ====> Epoch: 270 Average training (validation) loss: 1821.0324 (1822.4150)
# Epoch: 272 - Current Learning Rate: 0.00125
# ====> Epoch: 272 Average training (validation) loss: 1820.1144 (1821.5106)
# Epoch: 274 - Current Learning Rate: 0.00125
# ====> Epoch: 274 Average training (validation) loss: 1819.2319 (1820.6491)
# Epoch: 276 - Current Learning Rate: 0.00125
# ====> Epoch: 276 Average training (validation) loss: 1818.3725 (1819.7843)
# Epoch: 278 - Current Learning Rate: 0.00125
# ====> Epoch: 278 Average training (validation) loss: 1817.5358 (1818.9563)
# Epoch: 280 - Current Learning Rate: 0.00125
# ====> Epoch: 280 Average training (validation) loss: 1816.7017 (1818.1155)
# Epoch: 282 - Current Learning Rate: 0.00125
# ====> Epoch: 282 Average training (validation) loss: 1815.8673 (1817.2946)
# Epoch: 284 - Current Learning Rate: 0.00125
# ====> Epoch: 284 Average training (validation) loss: 1815.0334 (1816.4499)
# Epoch: 286 - Current Learning Rate: 0.00125
# ====> Epoch: 286 Average training (validation) loss: 1814.1857 (1815.6006)
# Epoch: 288 - Current Learning Rate: 0.00125
# ====> Epoch: 288 Average training (validation) loss: 1813.3429 (1814.7559)
# Epoch: 290 - Current Learning Rate: 0.00125
# ====> Epoch: 290 Average training (validation) loss: 1812.4846 (1813.9082)
# Epoch: 292 - Current Learning Rate: 0.00125
# ====> Epoch: 292 Average training (validation) loss: 1811.6195 (1813.0292)
# Epoch: 294 - Current Learning Rate: 0.00125
# ====> Epoch: 294 Average training (validation) loss: 1810.7464 (1812.1555)
# Epoch: 296 - Current Learning Rate: 0.00125
# ====> Epoch: 296 Average training (validation) loss: 1809.8687 (1811.2774)
# Epoch: 298 - Current Learning Rate: 0.00125
# ====> Epoch: 298 Average training (validation) loss: 1808.9842 (1810.3897)
# Epoch: 300 - Current Learning Rate: 0.00125
# ====> Epoch: 300 Average training (validation) loss: 1808.0958 (1809.4970)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 302 - Current Learning Rate: 0.00125
# ====> Epoch: 302 Average training (validation) loss: 1807.1976 (1808.6016)
# Epoch: 304 - Current Learning Rate: 0.00125
# ====> Epoch: 304 Average training (validation) loss: 1806.2856 (1807.6896)
# Epoch: 306 - Current Learning Rate: 0.00125
# ====> Epoch: 306 Average training (validation) loss: 1805.3788 (1806.7756)
# Epoch: 308 - Current Learning Rate: 0.00125
# ====> Epoch: 308 Average training (validation) loss: 1804.4530 (1805.8506)
# Epoch: 310 - Current Learning Rate: 0.00125
# ====> Epoch: 310 Average training (validation) loss: 1803.5278 (1804.9246)
# Epoch: 312 - Current Learning Rate: 0.00125
# ====> Epoch: 312 Average training (validation) loss: 1802.5938 (1803.9878)
# Epoch: 314 - Current Learning Rate: 0.00125
# ====> Epoch: 314 Average training (validation) loss: 1801.6633 (1803.0458)
# Epoch: 316 - Current Learning Rate: 0.00125
# ====> Epoch: 316 Average training (validation) loss: 1800.7040 (1802.0911)
# Epoch: 318 - Current Learning Rate: 0.00125
# ====> Epoch: 318 Average training (validation) loss: 1799.7464 (1801.1325)
# Epoch: 320 - Current Learning Rate: 0.00125
# ====> Epoch: 320 Average training (validation) loss: 1798.7918 (1800.1735)
# Epoch: 322 - Current Learning Rate: 0.00125
# ====> Epoch: 322 Average training (validation) loss: 1797.8723 (1799.2100)
# Epoch: 324 - Current Learning Rate: 0.00125
# ====> Epoch: 324 Average training (validation) loss: 1796.9447 (1798.2398)
# Epoch: 326 - Current Learning Rate: 0.00125
# ====> Epoch: 326 Average training (validation) loss: 1796.0124 (1797.2652)
# Epoch: 328 - Current Learning Rate: 0.00125
# ====> Epoch: 328 Average training (validation) loss: 1795.2568 (1796.3101)
# Epoch: 330 - Current Learning Rate: 0.00125
# ====> Epoch: 330 Average training (validation) loss: 1795.2526 (1795.4664)
# Epoch: 332 - Current Learning Rate: 0.00125
# ====> Epoch: 332 Average training (validation) loss: 1795.4675 (1794.8729)
# Epoch: 334 - Current Learning Rate: 0.00125
# ====> Epoch: 334 Average training (validation) loss: 1795.8369 (1793.8699)
# Epoch: 336 - Current Learning Rate: 0.00125
# ====> Epoch: 336 Average training (validation) loss: 1802.9241 (1794.4754)
# Epoch: 338 - Current Learning Rate: 0.00125
# ====> Epoch: 338 Average training (validation) loss: 1817.5730 (1795.4154)
# Epoch: 340 - Current Learning Rate: 0.000625
# ====> Epoch: 340 Average training (validation) loss: 1793.3985 (1793.7590)
# Epoch: 342 - Current Learning Rate: 0.000625
# ====> Epoch: 342 Average training (validation) loss: 1790.0467 (1791.5214)
# Epoch: 344 - Current Learning Rate: 0.000625
# ====> Epoch: 344 Average training (validation) loss: 1789.4408 (1791.0089)
# Epoch: 346 - Current Learning Rate: 0.000625
# ====> Epoch: 346 Average training (validation) loss: 1789.0670 (1790.6472)
# Epoch: 348 - Current Learning Rate: 0.000625
# ====> Epoch: 348 Average training (validation) loss: 1788.7151 (1790.2979)
# Epoch: 350 - Current Learning Rate: 0.000625
# ====> Epoch: 350 Average training (validation) loss: 1788.3737 (1789.9571)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 352 - Current Learning Rate: 0.000625
# ====> Epoch: 352 Average training (validation) loss: 1788.0365 (1789.6289)
# Epoch: 354 - Current Learning Rate: 0.000625
# ====> Epoch: 354 Average training (validation) loss: 1787.7164 (1789.3024)
# Epoch: 356 - Current Learning Rate: 0.000625
# ====> Epoch: 356 Average training (validation) loss: 1787.3970 (1788.9954)
# Epoch: 358 - Current Learning Rate: 0.000625
# ====> Epoch: 358 Average training (validation) loss: 1787.0963 (1788.7027)
# Epoch: 360 - Current Learning Rate: 0.000625
# ====> Epoch: 360 Average training (validation) loss: 1786.8040 (1788.4068)
# Epoch: 362 - Current Learning Rate: 0.000625
# ====> Epoch: 362 Average training (validation) loss: 1786.5211 (1788.1246)
# Epoch: 364 - Current Learning Rate: 0.000625
# ====> Epoch: 364 Average training (validation) loss: 1786.2449 (1787.8502)
# Epoch: 366 - Current Learning Rate: 0.000625
# ====> Epoch: 366 Average training (validation) loss: 1785.9748 (1787.5824)
# Epoch: 368 - Current Learning Rate: 0.000625
# ====> Epoch: 368 Average training (validation) loss: 1785.7001 (1787.3065)
# Epoch: 370 - Current Learning Rate: 0.000625
# ====> Epoch: 370 Average training (validation) loss: 1785.4267 (1787.0410)
# Epoch: 372 - Current Learning Rate: 0.000625
# ====> Epoch: 372 Average training (validation) loss: 1785.1550 (1786.7680)
# Epoch: 374 - Current Learning Rate: 0.000625
# ====> Epoch: 374 Average training (validation) loss: 1784.8872 (1786.4918)
# Epoch: 376 - Current Learning Rate: 0.000625
# ====> Epoch: 376 Average training (validation) loss: 1784.6103 (1786.2179)
# Epoch: 378 - Current Learning Rate: 0.000625
# ====> Epoch: 378 Average training (validation) loss: 1784.3343 (1785.9422)
# Epoch: 380 - Current Learning Rate: 0.000625
# ====> Epoch: 380 Average training (validation) loss: 1784.0556 (1785.6636)
# Epoch: 382 - Current Learning Rate: 0.000625
# ====> Epoch: 382 Average training (validation) loss: 1783.7788 (1785.3885)
# Epoch: 384 - Current Learning Rate: 0.000625
# ====> Epoch: 384 Average training (validation) loss: 1783.5003 (1785.1090)
# Epoch: 386 - Current Learning Rate: 0.000625
# ====> Epoch: 386 Average training (validation) loss: 1783.2199 (1784.8308)
# Epoch: 388 - Current Learning Rate: 0.000625
# ====> Epoch: 388 Average training (validation) loss: 1782.9386 (1784.5462)
# Epoch: 390 - Current Learning Rate: 0.000625
# ====> Epoch: 390 Average training (validation) loss: 1782.6552 (1784.2629)
# Epoch: 392 - Current Learning Rate: 0.000625
# ====> Epoch: 392 Average training (validation) loss: 1782.3722 (1783.9804)
# Epoch: 394 - Current Learning Rate: 0.000625
# ====> Epoch: 394 Average training (validation) loss: 1782.0899 (1783.7001)
# Epoch: 396 - Current Learning Rate: 0.000625
# ====> Epoch: 396 Average training (validation) loss: 1781.8050 (1783.4137)
# Epoch: 398 - Current Learning Rate: 0.000625
# ====> Epoch: 398 Average training (validation) loss: 1781.5250 (1783.1361)
# Epoch: 400 - Current Learning Rate: 0.000625
# ====> Epoch: 400 Average training (validation) loss: 1781.2450 (1782.8585)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 402 - Current Learning Rate: 0.000625
# ====> Epoch: 402 Average training (validation) loss: 1780.9704 (1782.5839)
# Epoch: 404 - Current Learning Rate: 0.000625
# ====> Epoch: 404 Average training (validation) loss: 1780.7038 (1782.3228)
# Epoch: 406 - Current Learning Rate: 0.000625
# ====> Epoch: 406 Average training (validation) loss: 1780.4475 (1782.0692)
# Epoch: 408 - Current Learning Rate: 0.000625
# ====> Epoch: 408 Average training (validation) loss: 1780.2101 (1781.8382)
# Epoch: 410 - Current Learning Rate: 0.000625
# ====> Epoch: 410 Average training (validation) loss: 1779.9886 (1781.6241)
# Epoch: 412 - Current Learning Rate: 0.000625
# ====> Epoch: 412 Average training (validation) loss: 1779.7883 (1781.4278)
# Epoch: 414 - Current Learning Rate: 0.000625
# ====> Epoch: 414 Average training (validation) loss: 1779.6015 (1781.2422)
# Epoch: 416 - Current Learning Rate: 0.000625
# ====> Epoch: 416 Average training (validation) loss: 1779.4322 (1781.0736)
# Epoch: 418 - Current Learning Rate: 0.000625
# ====> Epoch: 418 Average training (validation) loss: 1779.2620 (1780.9089)
# Epoch: 420 - Current Learning Rate: 0.000625
# ====> Epoch: 420 Average training (validation) loss: 1779.0996 (1780.7477)
# Epoch: 422 - Current Learning Rate: 0.000625
# ====> Epoch: 422 Average training (validation) loss: 1778.9402 (1780.5895)
# Epoch: 424 - Current Learning Rate: 0.000625
# ====> Epoch: 424 Average training (validation) loss: 1778.7821 (1780.4303)
# Epoch: 426 - Current Learning Rate: 0.000625
# ====> Epoch: 426 Average training (validation) loss: 1778.6211 (1780.2726)
# Epoch: 428 - Current Learning Rate: 0.000625
# ====> Epoch: 428 Average training (validation) loss: 1778.4636 (1780.1131)
# Epoch: 430 - Current Learning Rate: 0.000625
# ====> Epoch: 430 Average training (validation) loss: 1778.3069 (1779.9555)
# Epoch: 432 - Current Learning Rate: 0.000625
# ====> Epoch: 432 Average training (validation) loss: 1778.1596 (1779.8093)
# Epoch: 434 - Current Learning Rate: 0.000625
# ====> Epoch: 434 Average training (validation) loss: 1777.9935 (1779.6393)
# Epoch: 436 - Current Learning Rate: 0.000625
# ====> Epoch: 436 Average training (validation) loss: 1777.8312 (1779.4797)
# Epoch: 438 - Current Learning Rate: 0.000625
# ====> Epoch: 438 Average training (validation) loss: 1777.6697 (1779.3146)
# Epoch: 440 - Current Learning Rate: 0.000625
# ====> Epoch: 440 Average training (validation) loss: 1777.5096 (1779.1543)
# Epoch: 442 - Current Learning Rate: 0.000625
# ====> Epoch: 442 Average training (validation) loss: 1777.3423 (1778.9937)
# Epoch: 444 - Current Learning Rate: 0.000625
# ====> Epoch: 444 Average training (validation) loss: 1777.1866 (1778.8323)
# Epoch: 446 - Current Learning Rate: 0.000625
# ====> Epoch: 446 Average training (validation) loss: 1777.0587 (1778.6746)
# Epoch: 448 - Current Learning Rate: 0.000625
# ====> Epoch: 448 Average training (validation) loss: 1776.9644 (1778.5113)
# Epoch: 450 - Current Learning Rate: 0.000625
# ====> Epoch: 450 Average training (validation) loss: 1776.9414 (1778.3517)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 452 - Current Learning Rate: 0.000625
# ====> Epoch: 452 Average training (validation) loss: 1776.9526 (1778.2205)
# Epoch: 454 - Current Learning Rate: 0.000625
# ====> Epoch: 454 Average training (validation) loss: 1777.4379 (1778.0472)
# Epoch: 456 - Current Learning Rate: 0.000625
# ====> Epoch: 456 Average training (validation) loss: 1778.5134 (1778.2147)
# Epoch: 458 - Current Learning Rate: 0.000625
# ====> Epoch: 458 Average training (validation) loss: 1777.8091 (1777.9466)
# Epoch: 460 - Current Learning Rate: 0.000625
# ====> Epoch: 460 Average training (validation) loss: 1780.3876 (1778.3083)
# Epoch: 462 - Current Learning Rate: 0.000625
# ====> Epoch: 462 Average training (validation) loss: 1780.3075 (1778.3612)
# Epoch: 464 - Current Learning Rate: 0.000625
# ====> Epoch: 464 Average training (validation) loss: 1782.1006 (1777.8668)
# Epoch: 466 - Current Learning Rate: 0.0003125
# ====> Epoch: 466 Average training (validation) loss: 1775.6013 (1777.1974)
# Epoch: 468 - Current Learning Rate: 0.0003125
# ====> Epoch: 468 Average training (validation) loss: 1775.3613 (1777.0323)
# Epoch: 470 - Current Learning Rate: 0.0003125
# ====> Epoch: 470 Average training (validation) loss: 1775.2658 (1776.9401)
# Epoch: 472 - Current Learning Rate: 0.0003125
# ====> Epoch: 472 Average training (validation) loss: 1775.1813 (1776.8559)
# Epoch: 474 - Current Learning Rate: 0.0003125
# ====> Epoch: 474 Average training (validation) loss: 1775.0959 (1776.7725)
# Epoch: 476 - Current Learning Rate: 0.0003125
# ====> Epoch: 476 Average training (validation) loss: 1775.0121 (1776.6883)
# Epoch: 478 - Current Learning Rate: 0.0003125
# ====> Epoch: 478 Average training (validation) loss: 1774.9273 (1776.6031)
# Epoch: 480 - Current Learning Rate: 0.0003125
# ====> Epoch: 480 Average training (validation) loss: 1774.8432 (1776.5189)
# Epoch: 482 - Current Learning Rate: 0.0003125
# ====> Epoch: 482 Average training (validation) loss: 1774.7574 (1776.4320)
# Epoch: 484 - Current Learning Rate: 0.0003125
# ====> Epoch: 484 Average training (validation) loss: 1774.6719 (1776.3479)
# Epoch: 486 - Current Learning Rate: 0.0003125
# ====> Epoch: 486 Average training (validation) loss: 1774.5859 (1776.2632)
# Epoch: 488 - Current Learning Rate: 0.0003125
# ====> Epoch: 488 Average training (validation) loss: 1774.5020 (1776.1768)
# Epoch: 490 - Current Learning Rate: 0.0003125
# ====> Epoch: 490 Average training (validation) loss: 1774.4164 (1776.0894)
# Epoch: 492 - Current Learning Rate: 0.0003125
# ====> Epoch: 492 Average training (validation) loss: 1774.3298 (1776.0044)
# Epoch: 494 - Current Learning Rate: 0.0003125
# ====> Epoch: 494 Average training (validation) loss: 1774.2418 (1775.9168)
# Epoch: 496 - Current Learning Rate: 0.0003125
# ====> Epoch: 496 Average training (validation) loss: 1774.1554 (1775.8309)
# Epoch: 498 - Current Learning Rate: 0.0003125
# ====> Epoch: 498 Average training (validation) loss: 1774.0680 (1775.7470)
# Epoch: 500 - Current Learning Rate: 0.0003125
# ====> Epoch: 500 Average training (validation) loss: 1773.9801 (1775.6548)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 502 - Current Learning Rate: 0.0003125
# ====> Epoch: 502 Average training (validation) loss: 1773.8921 (1775.5679)
# Epoch: 504 - Current Learning Rate: 0.0003125
# ====> Epoch: 504 Average training (validation) loss: 1773.8048 (1775.4801)
# Epoch: 506 - Current Learning Rate: 0.0003125
# ====> Epoch: 506 Average training (validation) loss: 1773.7181 (1775.3957)
# Epoch: 508 - Current Learning Rate: 0.0003125
# ====> Epoch: 508 Average training (validation) loss: 1773.6279 (1775.3034)
# Epoch: 510 - Current Learning Rate: 0.0003125
# ====> Epoch: 510 Average training (validation) loss: 1773.5409 (1775.2191)
# Epoch: 512 - Current Learning Rate: 0.0003125
# ====> Epoch: 512 Average training (validation) loss: 1773.4533 (1775.1296)
# Epoch: 514 - Current Learning Rate: 0.0003125
# ====> Epoch: 514 Average training (validation) loss: 1773.3627 (1775.0405)
# Epoch: 516 - Current Learning Rate: 0.0003125
# ====> Epoch: 516 Average training (validation) loss: 1773.2744 (1774.9511)
# Epoch: 518 - Current Learning Rate: 0.0003125
# ====> Epoch: 518 Average training (validation) loss: 1773.1838 (1774.8602)
# Epoch: 520 - Current Learning Rate: 0.0003125
# ====> Epoch: 520 Average training (validation) loss: 1773.0953 (1774.7706)
# Epoch: 522 - Current Learning Rate: 0.0003125
# ====> Epoch: 522 Average training (validation) loss: 1773.0067 (1774.6810)
# Epoch: 524 - Current Learning Rate: 0.0003125
# ====> Epoch: 524 Average training (validation) loss: 1772.9169 (1774.5998)
# Epoch: 526 - Current Learning Rate: 0.0003125
# ====> Epoch: 526 Average training (validation) loss: 1772.8277 (1774.5007)
# Epoch: 528 - Current Learning Rate: 0.0003125
# ====> Epoch: 528 Average training (validation) loss: 1772.7351 (1774.4089)
# Epoch: 530 - Current Learning Rate: 0.0003125
# ====> Epoch: 530 Average training (validation) loss: 1772.6441 (1774.3188)
# Epoch: 532 - Current Learning Rate: 0.0003125
# ====> Epoch: 532 Average training (validation) loss: 1772.5558 (1774.2305)
# Epoch: 534 - Current Learning Rate: 0.0003125
# ====> Epoch: 534 Average training (validation) loss: 1772.4636 (1774.1391)
# Epoch: 536 - Current Learning Rate: 0.0003125
# ====> Epoch: 536 Average training (validation) loss: 1772.3745 (1774.0547)
# Epoch: 538 - Current Learning Rate: 0.0003125
# ====> Epoch: 538 Average training (validation) loss: 1772.2811 (1773.9554)
# Epoch: 540 - Current Learning Rate: 0.0003125
# ====> Epoch: 540 Average training (validation) loss: 1772.1898 (1773.8671)
# Epoch: 542 - Current Learning Rate: 0.0003125
# ====> Epoch: 542 Average training (validation) loss: 1772.0994 (1773.7757)
# Epoch: 544 - Current Learning Rate: 0.0003125
# ====> Epoch: 544 Average training (validation) loss: 1772.0062 (1773.6848)
# Epoch: 546 - Current Learning Rate: 0.0003125
# ====> Epoch: 546 Average training (validation) loss: 1771.9164 (1773.5926)
# Epoch: 548 - Current Learning Rate: 0.0003125
# ====> Epoch: 548 Average training (validation) loss: 1771.8306 (1773.5032)
# Epoch: 550 - Current Learning Rate: 0.0003125
# ====> Epoch: 550 Average training (validation) loss: 1771.7367 (1773.4097)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 552 - Current Learning Rate: 0.0003125
# ====> Epoch: 552 Average training (validation) loss: 1771.6426 (1773.3181)
# Epoch: 554 - Current Learning Rate: 0.0003125
# ====> Epoch: 554 Average training (validation) loss: 1771.5535 (1773.2279)
# Epoch: 556 - Current Learning Rate: 0.0003125
# ====> Epoch: 556 Average training (validation) loss: 1771.4640 (1773.1385)
# Epoch: 558 - Current Learning Rate: 0.0003125
# ====> Epoch: 558 Average training (validation) loss: 1771.3689 (1773.0438)
# Epoch: 560 - Current Learning Rate: 0.0003125
# ====> Epoch: 560 Average training (validation) loss: 1771.2770 (1772.9525)
# Epoch: 562 - Current Learning Rate: 0.0003125
# ====> Epoch: 562 Average training (validation) loss: 1771.1823 (1772.8575)
# Epoch: 564 - Current Learning Rate: 0.0003125
# ====> Epoch: 564 Average training (validation) loss: 1771.0919 (1772.7657)
# Epoch: 566 - Current Learning Rate: 0.0003125
# ====> Epoch: 566 Average training (validation) loss: 1770.9970 (1772.6747)
# Epoch: 568 - Current Learning Rate: 0.0003125
# ====> Epoch: 568 Average training (validation) loss: 1770.9055 (1772.5803)
# Epoch: 570 - Current Learning Rate: 0.0003125
# ====> Epoch: 570 Average training (validation) loss: 1770.8147 (1772.4935)
# Epoch: 572 - Current Learning Rate: 0.0003125
# ====> Epoch: 572 Average training (validation) loss: 1770.7255 (1772.3990)
# Epoch: 574 - Current Learning Rate: 0.0003125
# ====> Epoch: 574 Average training (validation) loss: 1770.6276 (1772.2990)
# Epoch: 576 - Current Learning Rate: 0.0003125
# ====> Epoch: 576 Average training (validation) loss: 1770.5436 (1772.2100)
# Epoch: 578 - Current Learning Rate: 0.0003125
# ====> Epoch: 578 Average training (validation) loss: 1770.4636 (1772.1163)
# Epoch: 580 - Current Learning Rate: 0.0003125
# ====> Epoch: 580 Average training (validation) loss: 1770.4591 (1772.0280)
# Epoch: 582 - Current Learning Rate: 0.0003125
# ====> Epoch: 582 Average training (validation) loss: 1770.4187 (1771.9404)
# Epoch: 584 - Current Learning Rate: 0.0003125
# ====> Epoch: 584 Average training (validation) loss: 1770.4277 (1771.8420)
# Epoch: 586 - Current Learning Rate: 0.0003125
# ====> Epoch: 586 Average training (validation) loss: 1770.6697 (1771.8109)
# Epoch: 588 - Current Learning Rate: 0.0003125
# ====> Epoch: 588 Average training (validation) loss: 1770.4511 (1771.6839)
# Epoch: 590 - Current Learning Rate: 0.0003125
# ====> Epoch: 590 Average training (validation) loss: 1770.6983 (1771.6707)
# Epoch: 592 - Current Learning Rate: 0.0003125
# ====> Epoch: 592 Average training (validation) loss: 1770.8201 (1771.5871)
# Epoch: 594 - Current Learning Rate: 0.0003125
# ====> Epoch: 594 Average training (validation) loss: 1770.4742 (1771.4736)
# Epoch: 596 - Current Learning Rate: 0.0003125
# ====> Epoch: 596 Average training (validation) loss: 1770.6427 (1771.3902)
# Epoch: 598 - Current Learning Rate: 0.0003125
# ====> Epoch: 598 Average training (validation) loss: 1770.7217 (1771.3647)
# Epoch: 600 - Current Learning Rate: 0.0003125
# ====> Epoch: 600 Average training (validation) loss: 1770.0686 (1771.2162)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 602 - Current Learning Rate: 0.0003125
# ====> Epoch: 602 Average training (validation) loss: 1769.7841 (1771.0372)
# Epoch: 604 - Current Learning Rate: 0.0003125
# ====> Epoch: 604 Average training (validation) loss: 1770.0546 (1770.9996)
# Epoch: 606 - Current Learning Rate: 0.0003125
# ====> Epoch: 606 Average training (validation) loss: 1769.6558 (1770.8495)
# Epoch: 608 - Current Learning Rate: 0.0003125
# ====> Epoch: 608 Average training (validation) loss: 1770.0225 (1770.8220)
# Epoch: 610 - Current Learning Rate: 0.0003125
# ====> Epoch: 610 Average training (validation) loss: 1769.8028 (1770.7453)
# Epoch: 612 - Current Learning Rate: 0.0003125
# ====> Epoch: 612 Average training (validation) loss: 1769.4308 (1770.5493)
# Epoch: 614 - Current Learning Rate: 0.0003125
# ====> Epoch: 614 Average training (validation) loss: 1769.6774 (1770.4724)
# Epoch: 616 - Current Learning Rate: 0.0003125
# ====> Epoch: 616 Average training (validation) loss: 1769.6355 (1770.4645)
# Epoch: 618 - Current Learning Rate: 0.0003125
# ====> Epoch: 618 Average training (validation) loss: 1769.6545 (1770.3572)
# Epoch: 620 - Current Learning Rate: 0.00015625
# ====> Epoch: 620 Average training (validation) loss: 1768.5962 (1770.2487)
# Epoch: 622 - Current Learning Rate: 0.00015625
# ====> Epoch: 622 Average training (validation) loss: 1768.4091 (1770.0981)
# Epoch: 624 - Current Learning Rate: 0.00015625
# ====> Epoch: 624 Average training (validation) loss: 1768.3494 (1770.0441)
# Epoch: 626 - Current Learning Rate: 0.00015625
# ====> Epoch: 626 Average training (validation) loss: 1768.2998 (1769.9932)
# Epoch: 628 - Current Learning Rate: 0.00015625
# ====> Epoch: 628 Average training (validation) loss: 1768.2522 (1769.9441)
# Epoch: 630 - Current Learning Rate: 7.8125e-05
# ====> Epoch: 630 Average training (validation) loss: 1768.2197 (1769.9195)
# Epoch: 632 - Current Learning Rate: 7.8125e-05
# ====> Epoch: 632 Average training (validation) loss: 1768.1951 (1769.8945)
# Epoch: 634 - Current Learning Rate: 7.8125e-05
# ====> Epoch: 634 Average training (validation) loss: 1768.1709 (1769.8707)
# Epoch: 636 - Current Learning Rate: 7.8125e-05
# ====> Epoch: 636 Average training (validation) loss: 1768.1468 (1769.8462)
# Epoch: 638 - Current Learning Rate: 7.8125e-05
# ====> Epoch: 638 Average training (validation) loss: 1768.1220 (1769.8214)
# Epoch: 640 - Current Learning Rate: 3.90625e-05
# ====> Epoch: 640 Average training (validation) loss: 1768.1058 (1769.8087)
# Epoch: 642 - Current Learning Rate: 3.90625e-05
# ====> Epoch: 642 Average training (validation) loss: 1768.0935 (1769.7964)
# Epoch: 644 - Current Learning Rate: 1.953125e-05
# ====> Epoch: 644 Average training (validation) loss: 1768.0826 (1769.7871)
# Epoch: 646 - Current Learning Rate: 1.953125e-05
# ====> Epoch: 646 Average training (validation) loss: 1768.0763 (1769.7810)
# Epoch: 648 - Current Learning Rate: 1.953125e-05
# ====> Epoch: 648 Average training (validation) loss: 1768.0701 (1769.7748)
# Epoch: 650 - Current Learning Rate: 9.765625e-06
# ====> Epoch: 650 Average training (validation) loss: 1768.0661 (1769.7716)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 652 - Current Learning Rate: 9.765625e-06
# ====> Epoch: 652 Average training (validation) loss: 1768.0629 (1769.7685)
# Epoch: 654 - Current Learning Rate: 4.8828125e-06
# ====> Epoch: 654 Average training (validation) loss: 1768.0601 (1769.7662)
# Epoch: 656 - Current Learning Rate: 4.8828125e-06
# ====> Epoch: 656 Average training (validation) loss: 1768.0586 (1769.7645)
# Epoch: 658 - Current Learning Rate: 4.8828125e-06
# ====> Epoch: 658 Average training (validation) loss: 1768.0570 (1769.7630)
# Epoch: 660 - Current Learning Rate: 2.44140625e-06
# ====> Epoch: 660 Average training (validation) loss: 1768.0560 (1769.7621)
# Epoch: 662 - Current Learning Rate: 2.44140625e-06
# ====> Epoch: 662 Average training (validation) loss: 1768.0552 (1769.7614)
# Epoch: 664 - Current Learning Rate: 1.220703125e-06
# ====> Epoch: 664 Average training (validation) loss: 1768.0545 (1769.7609)
# Epoch: 666 - Current Learning Rate: 1.220703125e-06
# ====> Epoch: 666 Average training (validation) loss: 1768.0541 (1769.7604)
# Epoch: 668 - Current Learning Rate: 1.220703125e-06
# ====> Epoch: 668 Average training (validation) loss: 1768.0537 (1769.7601)
# Epoch: 670 - Current Learning Rate: 6.103515625e-07
# ====> Epoch: 670 Average training (validation) loss: 1768.0534 (1769.7598)
# Epoch: 672 - Current Learning Rate: 6.103515625e-07
# ====> Epoch: 672 Average training (validation) loss: 1768.0532 (1769.7596)
# Epoch: 674 - Current Learning Rate: 3.0517578125e-07
# ====> Epoch: 674 Average training (validation) loss: 1768.0531 (1769.7595)
# Epoch: 676 - Current Learning Rate: 3.0517578125e-07
# ====> Epoch: 676 Average training (validation) loss: 1768.0529 (1769.7595)
# Epoch: 678 - Current Learning Rate: 3.0517578125e-07
# ====> Epoch: 678 Average training (validation) loss: 1768.0529 (1769.7592)
# Epoch: 680 - Current Learning Rate: 1.52587890625e-07
# ====> Epoch: 680 Average training (validation) loss: 1768.0528 (1769.7592)
# Epoch: 682 - Current Learning Rate: 1.52587890625e-07
# ====> Epoch: 682 Average training (validation) loss: 1768.0527 (1769.7592)
# Epoch: 684 - Current Learning Rate: 7.62939453125e-08
# ====> Epoch: 684 Average training (validation) loss: 1768.0527 (1769.7591)
# Epoch: 686 - Current Learning Rate: 7.62939453125e-08
# ====> Epoch: 686 Average training (validation) loss: 1768.0527 (1769.7591)
# Epoch: 688 - Current Learning Rate: 7.62939453125e-08
# ====> Epoch: 688 Average training (validation) loss: 1768.0527 (1769.7591)
# Epoch: 690 - Current Learning Rate: 3.814697265625e-08
# ====> Epoch: 690 Average training (validation) loss: 1768.0527 (1769.7591)
# Epoch: 692 - Current Learning Rate: 3.814697265625e-08
# ====> Epoch: 692 Average training (validation) loss: 1768.0527 (1769.7591)
# Epoch: 694 - Current Learning Rate: 1.9073486328125e-08
# ====> Epoch: 694 Average training (validation) loss: 1768.0527 (1769.7592)
# Epoch: 696 - Current Learning Rate: 1.9073486328125e-08
# ====> Epoch: 696 Average training (validation) loss: 1768.0527 (1769.7592)
# Epoch: 698 - Current Learning Rate: 1.9073486328125e-08
# ====> Epoch: 698 Average training (validation) loss: 1768.0527 (1769.7592)
# Epoch: 700 - Current Learning Rate: 1.9073486328125e-08
# ====> Epoch: 700 Average training (validation) loss: 1768.0527 (1769.7592)
# tensor([[1.],
#         [1.],
#         [1.],
#         ...,
#         [1.],
#         [1.],
#         [1.]], device='cuda:0')
# Epoch: 702 - Current Learning Rate: 1.9073486328125e-08
# ====> Epoch: 702 Average training (validation) loss: 1768.0527 (1769.7592)
# Early stopping

# %%
model.eval()

labels = [1000,500]

n_events = 100
z = torch.randn(n_events, latent_dim).to(device)  # Adjust latent_dim to 30
label_tensor = torch.tensor(np.tile(labels, n_events).reshape(n_events, 2)).to(device)
                              
# Generate signal
signal = model.decoder(z, label_tensor).to("cpu").detach().numpy()
print(signal)

generate_and_plot(dummy, model, labels, latent_dim, 100)

# %%
plt.plot(range(len(train_losses) -1), train_losses[1:], label="train set", color="green")
plt.plot(range(len(val_losses) -1), val_losses[1:], label="validation set", color="blue")

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.title("Loss")
plt.yscale('log')

plt.legend()
plt.show()

plt.plot(range(len(learning_rate)), learning_rate, label="Learning rate", color="green")

plt.xlabel("Epochs")
plt.ylabel("Learning rate")
plt.title("Learning rate")
plt.yscale('log')

plt.legend()
plt.show()

# %%
def plot_generated(df, signal, real_mX, real_mS):

    custom = np.linspace(0, 1, 50)

    filtered_df = df[(df['real_mX'] == real_mX) & (df['real_mS'] == real_mS)]

    plt.hist(filtered_df["PNN_score"][:len(signal)], alpha=0.7, density=True, bins=custom, label = "real")
    plt.hist(signal, alpha=0.7, density=True, bins=custom, label = "fake")
    plt.xlabel('PNN('+str(int(real_mX))+", "+str(int(real_mS))+')')
    plt.ylabel('Arbitrary units')
    plt.title('Distribution to learn')
    plt.xlim(0, 1)  # Force x-axis range to [0, 1]
    plt.legend()
    plt.grid(True)
    plt.show()


z = torch.randn(100, latent_dim).to(device)  # Adjust latent_dim to 30labels = torch.tensor(np.tile(labels, n_events).reshape(n_events, 2)).to(device)
                              
    # Generate signal
signal = model.decoder(z, labels).to("cpu").detach().numpy()

plot_generated(data, generated_signal, 185, 30)
# Out:
#   Cell In[17], line 21
#     signal = model.decoder(z, labels).to("cpu").detach().numpy()
#     ^
# IndentationError: unexpected indent
